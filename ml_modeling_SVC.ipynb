# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
#from imblearn.over_sampling import SMOTE
import pandas as pd 
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score
from sklearn.semi_supervised import SelfTrainingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('df4.csv', encoding='ISO-8859-1')
df1.head()
# Out:
#                                         cleaned_text sentiment
# 0                                          what said   neutral
# 1  plus youve added commercials to the experience...  positive
# 2  i didnt today must mean i need to take another...   neutral
# 3  its really aggressive to blast obnoxious enter...       NaN
# 4            and its a really big bad thing about it  negative

# %% [markdown]
# ## turn unlabled to -1 *rules of selfTrainClassifier

# %%
X = df1["cleaned_text"]
y = df1["sentiment"]

y[y.isna()] = -1
print(y.isna().sum())
# Out:
# 0

# %%
y = y.map({
    -1:-1,
    "negative":0,
    "neutral": 1,
    "positive": 2
})

# %%
X_labeled = X[y != -1]
y_labeled = y[y != -1]

X_unlabeled = X[y == -1]
y_unlabeled = y[y == -1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X_labeled,y_labeled,test_size=0.2)
X_train = pd.concat([X_train,X_unlabeled])
y_train = pd.concat([y_train,y_unlabeled])

# %% [markdown]
# ## Applying SVC

# %%
model8 = Pipeline(steps=[
    ("tfidf", TfidfVectorizer()),
    ("model", SelfTrainingClassifier(SVC(kernel='linear', probability=True)))  # Set probability=True
])

# %%
model8.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('model',
#                  SelfTrainingClassifier(base_estimator=SVC(kernel='linear',
#                                                            probability=True)))])

# %%
y_pred = model8.predict(X_test)

# %%
# Compute F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # You can change the average parameter based on your needs
print("F1 Score is : ", f1)
# Out:
# F1 Score is :  0.7810278813478014

# %%
# Print the accuracy score
print("Accuracy Score is : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score is :  0.790552077404667

# %%
# Print the classification report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:\n", classification_rep)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1122
#            1       0.64      0.50      0.56       366
#            2       0.78      0.63      0.70       269
#
#     accuracy                           0.79      1757
#    macro avg       0.75      0.69      0.71      1757
# weighted avg       0.78      0.79      0.78      1757

# %% [markdown]
# ## Applying SVC using Over-sampling with SMOTE

# %%
model = Pipeline(steps=[
    ("tfidf", TfidfVectorizer()),
    ("smote", SMOTE()), 
    ("model", SelfTrainingClassifier(SVC(kernel='linear', probability=True)))  # Set probability=True
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('smote', SMOTE()),
#                 ('model',
#                  SelfTrainingClassifier(base_estimator=SVC(kernel='linear',
#                                                            probability=True)))])

# %%
y_pred = model.predict(X_test)

# %%
# Compute F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # You can change the average parameter based on your needs
print("F1 Score is : ", f1)
# Out:
# F1 Score is :  0.7641945647892124

# %%
# Print the accuracy score
print("Accuracy Score is : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score is :  0.7626636311895276

# %%
# Print the classification report
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:\n", classification_rep)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      1122
#            1       0.55      0.60      0.58       366
#            2       0.70      0.65      0.67       269
#
#     accuracy                           0.76      1757
#    macro avg       0.70      0.70      0.70      1757
# weighted avg       0.77      0.76      0.76      1757
